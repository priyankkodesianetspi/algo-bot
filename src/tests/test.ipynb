# 335  3109.470882  3087.333249  -774391  7.536228e+05  24.989097  -96.0
# 336  3080.726647  3077.730334 -1720266  8.167998e+05  30.166543 -100.0
# 337  3065.706025  3075.613634  -955981  1.181131e+06  33.588292  -32.0
# 338  3057.437854  3076.721399  -467087  1.320815e+06  34.843012  -32.0
# 339  3052.262167  3076.884201  -234689  1.503933e+06  35.783695  -32.0
# 340  3051.618840  3081.489958   314029  1.984123e+06  33.943179  -32.0
# 341  3051.108225  3081.308073   310513  1.986287e+06  32.269983  -32.0
#
#           macd  macd_diff  macd_signal
# 330   2.368756   0.980288     1.388468
# 331   1.942183   0.442973     1.499211
# 332   1.733420   0.187367     1.546053
# 333   1.314776  -0.185021     1.499797
# 334  -6.566665  -6.453170    -0.113495
# 335 -14.776722 -11.730581    -3.046140
# 336 -22.891418 -15.876222    -7.015196
# 337 -26.690780 -15.740467   -10.950313
# 338 -27.420870 -13.176445   -14.244424
# 339 -26.459875  -9.772361   -16.687514
# 340 -21.763827  -4.061050   -17.702777
# 341 -17.892407  -0.151704   -17.740703
#
# [12 rows x 21 columns]

# %%
from src.indicators import get_indicators

data = get_indicators(data)
# data.dropna(inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.indicators import get_indicators
#       3 data = get_indicators(data)
#       4 # data.dropna(inplace=True)
#
# File ~/Documents/p_workspace/algo-bot/src/indicators.py:4
#       2 import pandas as pd
#       3 from flask import Flask, request
# ----> 4 import ta
#       5 from ta import add_all_ta_features
#       6 from ta.volatility import AverageTrueRange
#
# ModuleNotFoundError: No module named 'ta'

# %%
from src.data.selected_nifty_companies import nifty50_companies
print(nifty50_companies.keys())
# Out:
# dict_keys(['ADANIENT', 'ADANIPORTS', 'ASIANPAINT', 'AXISBANK', 'BAJAJ-AUTO', 'BAJFINANCE', 'BAJAJFINSV', 'BHARTIARTL', 'BPCL', 'BRITANNIA', 'CIPLA', 'COALINDIA', 'DIVISLAB', 'DRREDDY', 'EICHERMOT', 'GRASIM', 'HCLTECH', 'HDFCBANK', 'HDFCLIFE', 'HEROMOTOCO', 'HINDALCO', 'HINDUNILVR', 'ICICIBANK', 'INDUSINDBK', 'INFY', 'ITC', 'JSWSTEEL', 'KOTAKBANK', 'LT', 'M&M', 'MARUTI', 'NESTLEIND', 'NTPC', 'ONGC', 'POWERGRID', 'RELIANCE', 'SBILIFE', 'SBIN', 'SUNPHARMA', 'TATACONSUM', 'TATAMOTORS', 'TATASTEEL', 'TCS', 'TECHM', 'TITAN', 'ULTRACEMCO', 'UPL', 'WIPRO'])
